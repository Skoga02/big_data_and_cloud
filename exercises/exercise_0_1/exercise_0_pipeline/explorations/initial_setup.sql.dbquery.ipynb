-- %%
SHOW CATALOGS;

CREATE CATALOG IF NOT EXISTS airbnb;

USE CATALOG airbnb;

CREATE SCHEMA IF NOT EXISTS hosts;
CREATE VOLUME IF NOT EXISTS hosts.csv_files;
SHOW SCHEMAS;
SHOW VOLUMES;
